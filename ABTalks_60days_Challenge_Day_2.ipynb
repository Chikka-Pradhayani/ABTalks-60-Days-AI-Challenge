# %% [markdown]
# <a href="https://colab.research.google.com/github/Chikka-Pradhayani/ABTalks-60-Days-AI-Challenge/blob/main/ABTalks_60days_Challenge_Day_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello,It's my ABTalks 60 days challenge day-2")
# Out:
# Hello,It's my ABTalks 60 days challenge day-2

# %%
sentence = input("Enter a sentence: ")
words = sentence.lower().split()
frequency = {}
for word in words:
    frequency[word] = frequency.get(word, 0) + 1
print("Word frequency is:", frequency)
# Out:
# Enter a sentence: AI is amazing and AI is powerful
# Word frequency is: {'ai': 2, 'is': 2, 'amazing': 1, 'and': 1, 'powerful': 1}

# %%
import string
text = input("Enter text: ")
cleaned_text = text.lower()
cleaned_text = cleaned_text.translate(
    str.maketrans("", "", string.punctuation)
)
cleaned_text = " ".join(cleaned_text.split())
print("Cleaned Text:",cleaned_text)
# Out:
# Enter text: Hello,   AI World! This is AWESOME.
# Cleaned Text: hello ai world this is awesome
