# %% [markdown]
# <a href="https://colab.research.google.com/github/Chikka-Pradhayani/ABTalks-60-Days-AI-Challenge/blob/main/Day-36.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

print("Current directory:", os.getcwd())
print("Day 36 Cloud Deployment started")
# Out:
# Current directory: /content
# Day 36 Cloud Deployment started

# %%
# !ls -la /content
# Out:
# total 16
# drwxr-xr-x 1 root root 4096 Sep 16 13:26 .
# drwxr-xr-x 1 root root 4096 Sep 18 13:35 ..
# drwxr-xr-x 4 root root 4096 Sep 16 13:26 .config
# drwxr-xr-x 1 root root 4096 Sep 16 13:26 sample_data

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-1bb349d4-101b-40a8-9064-0b29e487f77f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1bb349d4-101b-40a8-9064-0b29e487f77f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !ls -la
# Out:
# total 56
# drwxr-xr-x 1 root root  4096 Sep 18 13:50 .
# drwxr-xr-x 1 root root  4096 Sep 18 13:35 ..
# drwxr-xr-x 4 root root  4096 Sep 16 13:26 .config
# -rw-r--r-- 1 root root 38970 Sep 18 13:50 Day-35.ipynb
# drwxr-xr-x 1 root root  4096 Sep 16 13:26 sample_data

# %%
# !grep -n "FastAPI\|app =" day36.py
# Out:
# grep: day36.py: No such file or directory

# %%
# !pip install fastapi uvicorn httpx -q

# %%
import json

with open("/content/Day-35.ipynb", "r") as f:
    notebook = json.load(f)

for cell in notebook["cells"]:
    if cell["cell_type"] == "code":
        code = "".join(cell["source"])
        if "FastAPI" in code or "app =" in code:
            print("=" * 60)
            print(code)
# Out:
# ...
# import numpy as np
# import faiss
#
# from sklearn.feature_extraction.text import TfidfVectorizer
# from sklearn.metrics.pairwise import cosine_similarity
#
#
# documents = [
#     "Retrieval Augmented Generation combines retrieval with language generation.",
#     "FAISS is used for efficient similarity search over vector embeddings.",
#     "TF-IDF retrieves documents using keyword-based similarity.",
#     "FastAPI is a Python framework for building APIs.",
#     "Redis is an in-memory data store commonly used for caching."
# ]
#
#
# # Simple local embeddings for demonstration
# vectorizer = TfidfVectorizer()
# tfidf_matrix = vectorizer.fit_transform(documents)
#
# dimension = tfidf_matrix.shape[1]
#
# faiss_index = faiss.IndexFlatL2(dimension)
#
# vectors = tfidf_matrix.toarray().astype("float32")
# faiss_index.add(vectors)
#
#
# def faiss_search(query, k=2):
#     query_vector = vectorizer.transform([query]).toarray().astype("float32")
#
# ...

# %%
# !ls -lh /content/day36.py
# Out:
# ls: cannot access '/content/day36.py': No such file or directory

# %%
# !cat /content/day36.py
# Out:
# cat: /content/day36.py: No such file or directory

# %%
from fastapi import FastAPI

app = FastAPI()

# %%
# !pip install fastapi uvicorn httpx -q

# %%
# !ls -la /content
# Out:
# total 56
# drwxr-xr-x 1 root root  4096 Sep 18 13:50 .
# drwxr-xr-x 1 root root  4096 Sep 18 13:35 ..
# drwxr-xr-x 4 root root  4096 Sep 16 13:26 .config
# -rw-r--r-- 1 root root 38970 Sep 18 13:50 Day-35.ipynb
# drwxr-xr-x 1 root root  4096 Sep 16 13:26 sample_data

# %%
import os
print(os.path.exists("/content/day36.py"))
# Out:
# False

# %%
import json

with open("/content/Day-35.ipynb", "r") as f:
    notebook = json.load(f)

for i, cell in enumerate(notebook["cells"]):
    if cell["cell_type"] == "code":
        code = "".join(cell["source"])
        if "FastAPI" in code or "app =" in code:
            print(f"\n--- CELL {i} ---\n")
            print(code)
# Out:
# --- CELL 3 ---
#
# import numpy as np
# import faiss
#
# from sklearn.feature_extraction.text import TfidfVectorizer
# from sklearn.metrics.pairwise import cosine_similarity
#
#
# documents = [
#     "Retrieval Augmented Generation combines retrieval with language generation.",
#     "FAISS is used for efficient similarity search over vector embeddings.",
#     "TF-IDF retrieves documents using keyword-based similarity.",
#     "FastAPI is a Python framework for building APIs.",
#     "Redis is an in-memory data store commonly used for caching."
# ]
#
#
# # Simple local embeddings for demonstration
# vectorizer = TfidfVectorizer()
# tfidf_matrix = vectorizer.fit_transform(documents)
#
# dimension = tfidf_matrix.shape[1]
#
# faiss_index = faiss.IndexFlatL2(dimension)
#
# vectors = tfidf_matrix.toarray().astype("float32")
# faiss_index.add(vectors)
#
#
# def faiss_search(query, k=2):
#     query_vector = vectorizer.transform([query]).toarray().astype("float32")
#
# ...

# %%
import os

print("day36.py exists:", os.path.exists("/content/day36.py"))
print("\nFiles in /content:")
# !ls -lh /content
# Out:
# day36.py exists: False
#
# Files in /content:
# total 44K
# -rw-r--r-- 1 root root  39K Sep 18 13:50 Day-35.ipynb
# drwxr-xr-x 1 root root 4.0K Sep 16 13:26 sample_data

# %%
import json

with open("/content/Day-35.ipynb", "r") as f:
    nb = json.load(f)

for i, cell in enumerate(nb["cells"]):
    if cell["cell_type"] == "code":
        code = "".join(cell["source"])
        if "FastAPI" in code or "uvicorn" in code or "@app." in code:
            print(f"\n{'='*70}")
            print(f"CELL {i}")
            print(f"{'='*70}")
            print(code)
# Out:
# ...
# CELL 0
# ...
# !pip install -q fastapi uvicorn pytest faiss-cpu scikit-learn redis
#
# ...
# CELL 3
# ...
# import numpy as np
# import faiss
#
# from sklearn.feature_extraction.text import TfidfVectorizer
# from sklearn.metrics.pairwise import cosine_similarity
#
#
# documents = [
#     "Retrieval Augmented Generation combines retrieval with language generation.",
#     "FAISS is used for efficient similarity search over vector embeddings.",
#     "TF-IDF retrieves documents using keyword-based similarity.",
#     "FastAPI is a Python framework for building APIs.",
#     "Redis is an in-memory data store commonly used for caching."
# ]
#
#
# # Simple local embeddings for demonstration
# vectorizer = TfidfVectorizer()
# tfidf_matrix = vectorizer.fit_transform(documents)
#
# dimension = tfidf_matrix.shape[1]
#
# faiss_index = faiss.IndexFlatL2(dimension)
#
# vectors = tfidf_matrix.toarray().astype("float32")
# faiss_index.add(vectors)
#
#
# def faiss_search(query, k=2):
# ...

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-fe739507-c7a0-4b3d-8060-c870d2d94479" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fe739507-c7a0-4b3d-8060-c870d2d94479">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !ls -lh /content
# Out:
# total 84K
# -rw-r--r-- 1 root root  39K Sep 18 14:05 'Day-35 (1).ipynb'
# -rw-r--r-- 1 root root  39K Sep 18 13:50  Day-35.ipynb
# drwxr-xr-x 1 root root 4.0K Sep 16 13:26  sample_data

# %%
# %%writefile day36.py
from fastapi import FastAPI

app = FastAPI(title="Day 36 AI Backend")

@app.get("/")
def root():
    return {"message": "Day 36 backend is running"}

@app.get("/health")
def health():
    return {"status": "healthy"}

@app.get("/ask")
def ask(question: str):
    return {
        "question": question,
        "answer": "This response is generated by the Day 36 demo backend."
    }
# Out:
# Writing day36.py

# %%
# !pip install fastapi uvicorn -q

# %%
from day36 import app

print("FastAPI app loaded successfully")
# Out:
# FastAPI app loaded successfully

# %%
# !uvicorn day36:app --host 0.0.0.0 --port 8000
# Out:
# INFO:     Started server process [9690]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8000 (Press CTRL+C to quit)
# INFO:     Shutting down
# INFO:     Finished server process [9690]
# ERROR:    Traceback (most recent call last):
#   File "/usr/lib/python3.13/asyncio/runners.py", line 196, in run
#     return runner.run(main)
#            ~~~~~~~~~~^^^^^^
#   File "/usr/lib/python3.13/asyncio/runners.py", line 119, in run
#     return self._loop.run_until_complete(task)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "uvloop/loop.pyx", line 1512, in uvloop.loop.Loop.run_until_complete
#   File "uvloop/loop.pyx", line 1505, in uvloop.loop.Loop.run_until_complete
#     self.run_forever()
#   File "uvloop/loop.pyx", line 1379, in uvloop.loop.Loop.run_forever
#     self._run(mode)
#   File "uvloop/loop.pyx", line 557, in uvloop.loop.Loop._run
#     raise self._last_error
# ...

# %%
import subprocess
import time

server = subprocess.Popen(
    ["uvicorn", "day36:app", "--host", "0.0.0.0", "--port", "8000"]
)

time.sleep(3)

print("FastAPI server started")
# Out:
# FastAPI server started

# %%
import requests

response = requests.get("http://127.0.0.1:8000/health")

print("Status:", response.status_code)
print("Response:", response.json())
# Out:
# Status: 200
# Response: {'status': 'healthy'}

# %%
response = requests.get(
    "http://127.0.0.1:8000/ask",
    params={"question": "What is AI?"}
)

print("Status:", response.status_code)
print("Response:", response.json())
# Out:
# Status: 200
# Response: {'question': 'What is AI?', 'answer': 'This response is generated by the Day 36 demo backend.'}

# %%
# %%writefile requirements.txt
# fastapi
# uvicorn[standard]
# Out:
# Writing requirements.txt

# %%
# !cat requirements.txt
# Out:
# fastapi
# uvicorn[standard]

# %%
# %%writefile Dockerfile
# FROM python:3.11-slim
#
# WORKDIR /app
#
# COPY requirements.txt .
#
# RUN pip install --no-cache-dir -r requirements.txt
#
# COPY day36.py .
#
# EXPOSE 8000
#
# CMD ["uvicorn", "day36:app", "--host", "0.0.0.0", "--port", "8000"]
# Out:
# Writing Dockerfile

# %%
# !cat Dockerfile
# Out:
# FROM python:3.11-slim
#
# WORKDIR /app
#
# COPY requirements.txt .
#
# RUN pip install --no-cache-dir -r requirements.txt
#
# COPY day36.py .
#
# EXPOSE 8000
#
# CMD ["uvicorn", "day36:app", "--host", "0.0.0.0", "--port", "8000"]

# %%
# !docker --version
# Out:
# /bin/bash: line 1: docker: command not found

# %%
# %cd /content
# !ls
# Out:
# /content
# 'Day-35 (1).ipynb'   day36.py	  __pycache__	     sample_data
#  Day-35.ipynb	     Dockerfile   requirements.txt

# %%
# !docker build -t day36-backend .
# Out:
# /bin/bash: line 1: docker: command not found

# %%
# !docker images | head
# Out:
# /bin/bash: line 1: docker: command not found

# %%
# !docker run -d --name day36-container -p 8000:8000 day36-backend
# Out:
# /bin/bash: line 1: docker: command not found

# %%
# !docker ps
# Out:
# /bin/bash: line 1: docker: command not found

# %%
import requests

response = requests.get("http://127.0.0.1:8000/health")

print("Status:", response.status_code)
print("Response:", response.json())
# Out:
# Status: 200
# Response: {'status': 'healthy'}

# %%
response = requests.get(
    "http://127.0.0.1:8000/ask",
    params={"question": "What is AI?"}
)

print("Status:", response.status_code)
print("Response:", response.json())
# Out:
# Status: 200
# Response: {'question': 'What is AI?', 'answer': 'This response is generated by the Day 36 demo backend.'}

# %%
# !grep -RniE "api[_-]?key|secret|password|token|sk-[A-Za-z0-9]" day36.py requirements.txt Dockerfile || true

# %%
# %%writefile .gitignore
# __pycache__/
# *.pyc
# .ipynb_checkpoints/
# .env
# .venv/
# venv/
# Out:
# Writing .gitignore

# %%
# !ls -la
# Out:
# total 116
# drwxr-xr-x 1 root root  4096 Sep 18 14:23  .
# drwxr-xr-x 1 root root  4096 Sep 18 13:35  ..
# drwxr-xr-x 4 root root  4096 Sep 16 13:26  .config
# -rw-r--r-- 1 root root 38970 Sep 18 14:05 'Day-35 (1).ipynb'
# -rw-r--r-- 1 root root 38970 Sep 18 13:50  Day-35.ipynb
# -rw-r--r-- 1 root root   383 Sep 18 14:06  day36.py
# -rw-r--r-- 1 root root   212 Sep 18 14:21  Dockerfile
# -rw-r--r-- 1 root root    57 Sep 18 14:23  .gitignore
# drwxr-xr-x 2 root root  4096 Sep 18 14:07  __pycache__
# -rw-r--r-- 1 root root    26 Sep 18 14:20  requirements.txt
# drwxr-xr-x 1 root root  4096 Sep 16 13:26  sample_data

# %%
# %%writefile README.md
# # Day 36 - Cloud Deployment
#
# A Dockerized FastAPI backend prepared for cloud deployment.
#
# ## Endpoints
#
# - GET `/` - Backend status
# - GET `/health` - Health check
# - GET `/ask?question=...` - Demo question endpoint
#
# ## Run locally
#
# ```bash
# pip install -r requirements.txt
# uvicorn day36:app --host 0.0.0.0 --port 8000
# Out:
# Writing README.md

# %%
# !git config --global user.name "YourName"
# !git config --global user.email "your-email@example.com"

# %%
# %cd /content
# !git init
# !git add day36.py requirements.txt Dockerfile README.md .gitignore
# !git commit -m "Day 36: Dockerize FastAPI backend"
# Out:
# /content
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/.git/
# [master (root-commit) 4dfceb5] Day 36: Dockerize FastAPI backend
#  5 files changed, 54 insertions(+)
#  create mode 100644 .gitignore
#  create mode 100644 Dockerfile
#  create mode 100644 README.md
#  create mode 100644 day36.py
#  create mode 100644 requirements.txt

# %%
# !git branch -M main
# !git remote add origin https://github.com/Chikka-Pradhayani
# Out:
# error: remote origin already exists.

# %%
# !git push -u origin main
# Out:
# fatal: 'YOUR_GITHUB_REPOSITORY_URL' does not appear to be a git repository
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.
